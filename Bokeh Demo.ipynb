# %% [markdown]
# This notebook is based around reproducing the use of bokeh in [Visualizing Data with bokeh and pandas](https://programminghistorian.org/en/lessons/visualizing-with-bokeh). Let's get started.

# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show

# output_file is also an important method, but we are working in a notebook here

# for connecting DataFrame to bokeh
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
x = [1, 3, 5, 7]
y = [2, 4, 6, 8]
p = figure()
p.circle(x, y, size=10, color='red', legend_label='circle')
p.line(x, y, color='blue', legend_label='line')
p.triangle(y, x, color='gold', size=10, legend_label='triangle')
p.legend.click_policy='hide'
show(p)
# Out:
#   <div class="bk-root" id="d0fd2f71-f5b4-44ce-b778-e2c696b73f30" data-root-id="1003"></div>

# %%
df = pd.read_csv('thor_wwii.csv')
df
# Out:
#            MSNDATE      THEATER COUNTRY_FLYING_MISSION    NAF   UNIT_ID  \
# 0       03/30/1941          ETO          GREAT BRITAIN    RAF   84 SQDN
# 1       11/24/1940          ETO          GREAT BRITAIN    RAF  211 SQDN
# 2       12/04/1940          ETO          GREAT BRITAIN    RAF  211 SQDN
# 3       12/31/1940          ETO          GREAT BRITAIN    RAF  211 SQDN
# 4       01/06/1941          ETO          GREAT BRITAIN    RAF  211 SQDN
# ...            ...          ...                    ...    ...       ...
# 178276  08/01/1945          PTO                    USA  20 AF     73 BW
# 178277  07/22/1942          MTO          GREAT BRITAIN    RAF       NaN
# 178278  08/17/1940  EAST AFRICA          GREAT BRITAIN    RAF   47 SQDN
# 178279  08/06/1945          PTO                    USA  20 AF    509 CG
# 178280  08/09/1945          PTO                    USA  20 AF    509 CG
#
#        AIRCRAFT_NAME  AC_ATTACKING TAKEOFF_BASE TAKEOFF_COUNTRY  \
# ...

# %%
df.MSNDATE = pd.to_datetime(df.MSNDATE, format='%m/%d/%Y')
df.MSNDATE
# Out:
# 0        1941-03-30
# 1        1940-11-24
# 2        1940-12-04
# 3        1940-12-31
# 4        1941-01-06
#             ...
# 178276   1945-08-01
# 178277   1942-07-22
# 178278   1940-08-17
# 178279   1945-08-06
# 178280   1945-08-09
# Name: MSNDATE, Length: 178281, dtype: datetime64[ns]

# %%
# A subset of the data that will be easier to workwith
sample = df.sample(50)

p = figure(coef.squeeze()
